# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")   # pretrained

model.train(
    data="C:\Projects\Fall_Detection\data\data.yaml",
    epochs=5,
    imgsz=640,
    batch=16
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\weich\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.252  Python-3.11.13 torch-2.9.1+cpu CPU (AMD Ryzen 5 5500U with Radeon Graphics)
# ...
